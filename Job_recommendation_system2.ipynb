# %% [markdown]
# # Connect GDRIVE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Necessary libraries

# %%
# !pip install uszipcode --quiet
# Out:
#      |████████████████████████████████| 121 kB 47.5 MB/s
#      |████████████████████████████████| 76 kB 3.5 MB/s

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import ast 
from scipy import stats
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity

from gensim.models import Doc2Vec
import gensim.models.doc2vec
from collections import OrderedDict
import multiprocessing

from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.utils import simple_preprocess
from gensim.test.utils import get_tmpfile
from gensim.models.callbacks import CallbackAny2Vec

import pickle

from uszipcode import SearchEngine
from geopy.distance import distance

import gc
import re

import warnings; warnings.simplefilter('ignore')
# Out:
# /usr/local/lib/python3.8/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# # Utility functions

# %%
def preprocessor(text):
    text = text.replace('\\r', '').replace('&nbsp', '').replace('\n', '')
    text = re.sub('<[^>]*>', '', text)
    emoticons = re.findall('(?::|;|=)(?:-)?(?:\)|\(|D|P)', text)
    text = re.sub('[\W]+', ' ', text.lower()) +\
        ' '.join(emoticons).replace('-', '')
    return text

def user_exist(user):
    if len(users.loc[users['UserID'] == user]) == 0:
        return False
    return True

def has_coordinates(user):
    c = users.loc[users['UserID'] == user, "Coordinates"] 

    if (len(c) == 0) or (c.iloc[0].split(',')[0]) == 'None':
        return False
    return True

def user_profile(user_id):
    user_profile = np.array(users.loc[users['UserID'] == user_id, ['DegreeType', 'Major']])[0]
    historical_apps = user_history.loc[user_history.UserID == user_id, 'JobTitle']
    user_profile = """
    Degree Type: {}
    Major: {}
    """.format(user_profile[0], user_profile[1])

    return user_profile

def historical_application(user_id):
    historical_apps = apps.loc[apps.UserID == user_id]['JobID']
    content = list()
    for application in historical_apps:
        temp = jobs.loc[jobs.JobID == application, ['Title', 'Description', 'Requirements']]
        if len(temp) != 0:
            content += [temp.Title.values + ". " + temp.Description.values + ". " + temp.Requirements.values]
    return content

class EpochLogger(CallbackAny2Vec):
    '''Callback to log information about training'''

    def __init__(self):
        self.epoch = 0

    def on_epoch_begin(self, model):
        print("Epoch #{} start".format(self.epoch))
        self.epoch += 1

# %%
assert gensim.models.doc2vec.FAST_VERSION > -1, "SLOW VERSION"
MAX_DISTANCE = 15

# %% [markdown]
# # Reading datasets

# %%
folder = '/content/drive/MyDrive/job-recommendation-system/'

# %%
apps = pd.read_csv(folder+'data/apps.tsv', delimiter='\t', encoding='utf-8')
len
# Out:
# <function len(obj, /)>

# %%
user_history = pd.read_csv(folder+'data/user_history.tsv', delimiter='\t', encoding='utf-8')
user_history.head()
# Out:
#    UserID  WindowID  Split  Sequence  \
# 0      47         1  Train         1
# 1      47         1  Train         2
# 2      47         1  Train         3
# 3      72         1  Train         1
# 4      72         1  Train         2
#
#                                             JobTitle
# 0  National Space Communication Programs-Special ...
# 1                                  Detention Officer
# 2                            Passenger Screener, TSA
# 3               Lecturer, Department of Anthropology
# 4                                  Student Assistant

# %%
jobs = pd.read_csv(folder+'data/jobs.tsv', delimiter='\t', encoding='utf-8', error_bad_lines=False)
jobs.head()
# Out:
# b'Skipping line 122433: expected 11 fields, saw 12\n'
# b'Skipping line 602576: expected 11 fields, saw 12\n'
# b'Skipping line 990950: expected 11 fields, saw 12\n'
#    JobID  WindowID                             Title  \
# 0      1         1  Security Engineer/Technical Lead
# 1      4         1         SAP Business Analyst / WM
# 2      7         1     P/T HUMAN RESOURCES ASSISTANT
# 3      8         1            Route Delivery Drivers
# 4      9         1                      Housekeeping
#
#                                          Description  \
# 0  <p>Security Clearance Required:&nbsp; Top Secr...
# 1  <strong>NO Corp. to Corp resumes&nbsp;are bein...
# 2  <b>    <b> P/T HUMAN RESOURCES ASSISTANT</b> <...
# 3  CITY BEVERAGES Come to work for the best in th...
# 4  I make  sure every part of their day is magica...
#
#                                         Requirements         City State  \
# 0  <p>SKILL SET</p>\r<p>&nbsp;</p>\r<p>Network Se...   Washington    DC
# 1  <p><b>WHAT YOU NEED: </b></p>\r<p>Four year co...    Charlotte    NC
# 2  Please refer to the Job Description to view th...  Winter Park    FL
# 3  Please refer to the Job Description to view th...      Orlando    FL
# 4  Please refer to the Job Description to view th...      Orlando    FL
#
#   Country   Zip5                StartDate              EndDate
# 0      US  20531  2012-03-07 13:17:01.643  2012-04-06 23:59:59
# 1      US  28217  2012-03-21 02:03:44.137  2012-04-20 23:59:59
# 2      US  32792  2012-03-02 16:36:55.447  2012-04-01 23:59:59
# 3      US    NaN  2012-03-03 09:01:10.077  2012-04-02 23:59:59
# 4      US    NaN   2012-03-03 09:01:11.88  2012-04-02 23:59:59

# %%
users = pd.read_csv(folder+'data/users.tsv', delimiter='\t', encoding='utf-8')
users.head()
# Out:
#    UserID  WindowID  Split          City State Country ZipCode   DegreeType  \
# 0      47         1  Train     Paramount    CA      US   90723  High School
# 1      72         1  Train       La Mesa    CA      US   91941     Master's
# 2      80         1  Train  Williamstown    NJ      US   08094  High School
# 3      98         1  Train       Astoria    NY      US   11105     Master's
# 4     123         1  Train   Baton Rouge    LA      US   70808   Bachelor's
#
#                    Major       GraduationDate  WorkHistoryCount  \
# 0                    NaN  1999-06-01 00:00:00                 3
# 1           Anthropology  2011-01-01 00:00:00                10
# 2         Not Applicable  1985-06-01 00:00:00                 5
# 3             Journalism  2007-05-01 00:00:00                 3
# 4  Agricultural Business  2011-05-01 00:00:00                 1
#
#    TotalYearsExperience CurrentlyEmployed ManagedOthers  ManagedHowMany
# 0                  10.0               Yes            No               0
# 1                   8.0               Yes            No               0
# 2                  11.0               Yes           Yes               5
# 3                   3.0               Yes            No               0
# 4                   9.0               Yes            No               0

# %%
test_users = pd.read_csv(folder+'data/test_users.tsv', delimiter='\t', encoding='utf-8')
test_users.head()
# Out:
#    UserID  WindowID
# 0     767         1
# 1     769         1
# 2     861         1
# 3    1006         1
# 4    1192         1

# %%
print("Original number of jobs: ",len(jobs))
print("Original number of users: ",len(users))
# Out:
# Original number of jobs:  1091923
# Original number of users:  389708

# %% [markdown]
# # Pipeline - Preprocessing

# %% [markdown]
# ### Subsetting & Sampling users of NY state with 40% sampling

# %%
users = users.loc[users.State == 'NY']
users = users.sample(frac=0.4, replace=False, random_state=1)
len(users)
# Out:
# 8236

# %% [markdown]
# ### Subsetting jobs with zipcode of NY state for testing distance feature

# %%
jobs = jobs.loc[jobs.State == 'NY']
# all_jobs = jobs.copy()

# %%
jobs.Zip5 = jobs.Zip5.fillna(0)
jobs.Zip5 = jobs.Zip5.astype(int)
jobs = jobs.loc[jobs['Zip5'] != 0]
len(jobs)
# Out:
# 33679

# %% [markdown]
# ### Subsetting & Sampling jobs of NY state with 40% sampling

# %%
jobs = jobs.sample(frac=0.4, replace=False, random_state=1)
len(jobs)
# Out:
# 13472

# %% [markdown]
# ### Clearning Memory

# %%
gc.collect()
# Out:
# 15

# %% [markdown]
# ### Creating jobs coordinates and Communities

# %%
search = SearchEngine()
# Out:
# Download /root/.uszipcode/simple_db.sqlite from https://github.com/MacHu-GWU/uszipcode-project/releases/download/1.0.1.db/simple_db.sqlite ...
#   1.00 MB downloaded ...
#   2.00 MB downloaded ...
#   3.00 MB downloaded ...
#   4.00 MB downloaded ...
#   5.00 MB downloaded ...
#   6.00 MB downloaded ...
#   7.00 MB downloaded ...
#   8.00 MB downloaded ...
#   9.00 MB downloaded ...
#   10.00 MB downloaded ...
#   11.00 MB downloaded ...
#   Complete!

# %%
def coordinates(zipcode):
    zipcode = search.by_zipcode(zipcode)
    try:
      community = zipcode.post_office_city
      return community, "{},{}".format(zipcode.lat, zipcode.lng)
    except AttributeError:
      return None

# %%
# search.by_zipcode("2e").lat
# %%timeit
jobs["Community"] = ""
jobs["Coordinates"] = ""
for zipcode in jobs.Zip5.unique():
    try:
      community, coordinate = coordinates(zipcode)
      jobs.loc[jobs.Zip5 == zipcode, "Coordinates"] =  str(coordinate)
      jobs.loc[jobs.Zip5 == zipcode, "Community"] =  community
    except TypeError:
      print("cannot unpack non-iterable NoneType object")
# Out:
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# cannot unpack non-iterable NoneType object
# 1.67 s ± 178 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Creating user coordinates

# %%
def creating_coordinates(df, column):
    df["Community"] = ""
    df["Coordinates"] = "None, None"
    for zipcode in df[column].unique():
        try:
          community, coordinate = coordinates(zipcode)
          df.loc[df[column] == zipcode, "Coordinates"] =  str(coordinate)
          df.loc[df[column] == zipcode, "Community"] =  community
          return df
        except TypeError:
          pass
users = creating_coordinates(users, 'ZipCode')

# %% [markdown]
# ### Cleaning Description and Requirements

# %%
jobs['Description'] = jobs['Description'].astype(dtype='str').apply(preprocessor)

# %%
jobs['Requirements'] = jobs['Requirements'].astype(dtype='str').apply(preprocessor)

# %% [markdown]
# ### Making jobs profiles

# %%
jobs['profile'] = jobs['Title'].astype(str)  +  '. ' + jobs['Requirements'].astype(str) +  '. ' + jobs['Description'].astype(str)

# %% [markdown]
# ### Making users profiles

# %%
# %%timeit

users['profile'] =  (users['Major'].astype(str) +  " " ) + (users['DegreeType'].astype(str) + " ")

#Cleaning Garbage Words
users['profile'] = users['profile'].str.replace('None.', ' ')
users['profile'] = users['profile'].str.replace('Not Applicable', ' ')
users['profile'] = users['profile'].str.replace('nan', ' ')
# Out:
# 30.7 ms ± 18.1 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # EDA 2

# %% [markdown]
# ### Jobs by Communmties/County

# %%
jobs.groupby(['Community']).size().reset_index(name='Count').sort_values('Count', ascending=False).head(20)
# Out:
#                 Community  Count
# 325          New York, NY   4189
# 398         Rochester, NY    639
# 57            Buffalo, NY    494
# 55           Brooklyn, NY    426
# 53              Bronx, NY    337
# 292          Melville, NY    273
# 2              Albany, NY    228
# 504      White Plains, NY    191
# 453          Syracuse, NY    172
# 198         Hauppauge, NY    168
# 167       Garden City, NY    112
# 44         Binghamton, NY    103
# 272  Long Island City, NY     98
# 138            Elmira, NY     90
# 384      Poughkeepsie, NY     83
# 145       Farmingdale, NY     82
# 321     New Hyde Park, NY     80
# 516           Yonkers, NY     74
# 456         Tarrytown, NY     73
# 494     West Harrison, NY     68

# %% [markdown]
# ### Jobs by zipcode

# %%
jobs.groupby(['Community', 'Zip5', 'Coordinates']).size().reset_index(name='Count').sort_values('Count', ascending=False).head(20)
# Out:
#                 Community   Zip5   Coordinates  Count
# 452          New York, NY  10001   40.75,-74.0   1267
# 466          New York, NY  10017  40.75,-73.97    418
# 465          New York, NY  10016  40.75,-73.98    318
# 416          Melville, NY  11747  40.78,-73.41    273
# 485          New York, NY  10036  40.76,-73.99    257
# 467          New York, NY  10018  40.76,-73.99    225
# 471          New York, NY  10022  40.76,-73.97    179
# 313         Hauppauge, NY  11788  40.82,-73.21    168
# 456          New York, NY  10005  40.71,-74.01    166
# 502          New York, NY  10167  40.75,-73.97    155
# 102          Brooklyn, NY  11201  40.69,-73.99    154
# 455          New York, NY  10004  40.69,-74.02    152
# 468          New York, NY  10019  40.77,-73.99    140
# 756      White Plains, NY  10601  41.03,-73.77    117
# 279       Garden City, NY  11530  40.72,-73.64    112
# 611         Rochester, NY  14623  43.09,-77.64     99
# 395  Long Island City, NY  11101  40.74,-73.93     96
# 9              Albany, NY  12205  42.72,-73.83     96
# 460          New York, NY  10010  40.74,-73.98     93
# 487          New York, NY  10038   40.71,-74.0     85

# %% [markdown]
# ### Users by Community

# %%
users.groupby(['City', 'ZipCode', 'State']).size().reset_index(name='Count').sort_values('Count', ascending=False).head(20)
# Out:
#           City ZipCode State  Count
# 163   Brooklyn   11236    NY     66
# 152   Brooklyn   11226    NY     64
# 454    Jamaica   11434    NY     62
# 112      Bronx   10466    NY     57
# 161   Brooklyn   11234    NY     57
# 404  Hempstead   11550    NY     56
# 113      Bronx   10467    NY     55
# 137   Brooklyn   11212    NY     55
# 108      Bronx   10462    NY     54
# 104      Bronx   10458    NY     54
# 127   Brooklyn   11203    NY     53
# 98       Bronx   10453    NY     53
# 133   Brooklyn   11208    NY     53
# 132   Brooklyn   11207    NY     52
# 983    Yonkers   10701    NY     50
# 607   New York   10029    NY     48
# 452    Jamaica   11432    NY     45
# 582   New York   10001    NY     45
# 138   Brooklyn   11213    NY     45
# 146   Brooklyn   11221    NY     45

# %% [markdown]
# ### Training set

# %%
jobs.head()
# Out:
#           JobID  WindowID                                              Title  \
# 322649   268634         2  On-Call Office Services Associate (Scanning/Ma...
# 1073169  936381         7                   Coordinator, Corporate Marketing
# 91453    358280         1  Director of Concessions at Barclays Center/Bro...
# 527720   701181         3                      Marketing/Executive Assistant
# 316226   224741         2  Restaurant Manager - Grand Lux Cafe - Long Isl...
#
#                                                Description  \
# 322649   pitney bowes management services pbms provides...
# 1073169   gannett corporate marketing coordinator corpo...
# 91453    as a levy restaurants director of concessions ...
# 527720   the von group marketing executive assistant jo...
# 316226    ndescriptionthe restaurant manager is respons...
#
#                                               Requirements         City State  \
# 322649   the ideal candidate must be able to demonstrat...       Armonk    NY
# 1073169                                                        New York    NY
# 91453                                                  n a     Brooklyn    NY
# 527720   job requirements high aptitude for microsoft e...    Manhattan    NY
# 316226                                                      Garden City    NY
#
#         Country   Zip5                StartDate              EndDate  \
# 322649       US  10504  2012-04-16 14:03:48.903  2012-05-15 23:59:59
# 1073169      US  10001  2012-05-24 21:05:10.253  2012-06-23 23:59:00
# 91453        US  11217  2012-03-29 04:02:17.373  2012-04-28 23:59:59
# 527720       US  10016  2012-04-12 17:35:49.613  2012-05-11 23:59:59
# 316226       US  11530  2012-04-22 08:16:32.973  2012-05-21 23:59:59
#
#                Community   Coordinates  \
# 322649        Armonk, NY  41.13,-73.71
# 1073169     New York, NY   40.75,-74.0
# 91453       Brooklyn, NY  40.68,-73.98
# 527720      New York, NY  40.75,-73.98
# 316226   Garden City, NY  40.72,-73.64
#
#                                                    profile
# 322649   On-Call Office Services Associate (Scanning/Ma...
# 1073169  Coordinator, Corporate Marketing.  .  gannett ...
# 91453    Director of Concessions at Barclays Center/Bro...
# 527720   Marketing/Executive Assistant. job requirement...
# 316226   Restaurant Manager - Grand Lux Cafe - Long Isl...

# %%
users.head()
# Out:
#          UserID  WindowID  Split           City State Country ZipCode  \
# 200098   248008         4  Train       New York    NY      US   10003
# 286529  1184529         5  Train       New York    NY      US   10035
# 57797   1122774         1  Train   New Hartford    NY      US   13413
# 60141   1165147         1  Train  Staten Island    NY      US   10314
# 371308   875025         7  Train       Brooklyn    NY      US   11219
#
#          DegreeType                    Major       GraduationDate  \
# 200098         None   Electrical Engineering                  NaN
# 286529  High School           Not Applicable  2005-01-01 00:00:00
# 57797          None  Business Administration  1987-01-01 00:00:00
# 60141    Bachelor's      BA/Criminal Justice  1980-06-01 00:00:00
# 371308         None      Business Management  2009-01-01 00:00:00
#
#         WorkHistoryCount  TotalYearsExperience CurrentlyEmployed  \
# 200098                 2                  15.0               Yes
# 286529                 3                   7.0               NaN
# 57797                  2                  23.0               Yes
# 60141                  7                  35.0               Yes
# 371308                 8                   6.0               Yes
#
#        ManagedOthers  ManagedHowMany     Community   Coordinates  \
# 200098            No               0  New York, NY  40.73,-73.99
# 286529            No               0                  None, None
# 57797            Yes               8                  None, None
# 60141            Yes             200                  None, None
# 371308           Yes               8                  None, None
#
#                                 profile
# 200098         Electrical Engineering
# 286529                     High School
# 57797         Business Administration
# 60141   BA/Criminal Justice Bachelor's
# 371308            Business Management

# %% [markdown]
# # Machine Learninig Pipeline: NLP Model

# %%
# %%time
def similarities_nlp_model( model_name = folder+"jobs_doc2vec_model",
                 mapping_name = folder+"jobID_mapping.p", max_epochs = 100,
                 alpha = 0.025):
    
    document = list()
    jobID_mapping = dict()
        
    for i, token in enumerate(jobs['profile']):
        value = jobs.iloc[i]["JobID"]
        tokens = TaggedDocument(simple_preprocess(token), [i])
        document.append(tokens)
        jobID_mapping[i] = value

    epoch_logger = EpochLogger()
    model = Doc2Vec(size = 20, alpha=alpha, 
                    min_alpha=0.00025, min_count=2,
                    callbacks=[epoch_logger], dm =1, workers=8, window=2)
    
    model.build_vocab(document)
    print(model.corpus_count)
    for epoch in range(max_epochs):
        print('iteration {0}'.format(epoch))
        model.train(document, 
                    total_examples=model.corpus_count, 
                    epochs=model.iter)
        # decrease the learning rate
        model.alpha -= 0.0002
        # fix the learning rate, no decay
        model.min_alpha = model.alpha

    # create a dictionary
    pickle.dump(model, open(model_name, "wb")) 
    pickle.dump(jobID_mapping, open(mapping_name, "wb")) 

# -------------------------------------------------------------
# Load the dictionary back from the pickle file.
    return model, jobID_mapping

model, jobID_mapping = similarities_nlp_model()
# Out:
# 13472
# iteration 0
# Epoch #0 start
# Epoch #1 start
# Epoch #2 start
# Epoch #3 start
# Epoch #4 start
# WARNING:gensim.models.base_any2vec:Effective 'alpha' higher than previous training cycles
# iteration 1
# Epoch #5 start
# Epoch #6 start
# Epoch #7 start
# Epoch #8 start
# Epoch #9 start
# iteration 2
# Epoch #10 start
# Epoch #11 start
# Epoch #12 start
# Epoch #13 start
# Epoch #14 start
# iteration 3
# Epoch #15 start
# Epoch #16 start
# Epoch #17 start
# Epoch #18 start
# Epoch #19 start
# iteration 4
# Epoch #20 start
# Epoch #21 start
# Epoch #22 start
# Epoch #23 start
# Epoch #24 start
# iteration 5
# Epoch #25 start
# Epoch #26 start
# Epoch #27 start
# Epoch #28 start
# Epoch #29 start
# iteration 6
# Epoch #30 start
# Epoch #31 start
# Epoch #32 start
# Epoch #33 start
# Epoch #34 start
# iteration 7
# Epoch #35 start
# Epoch #36 start
# Epoch #37 start
# Epoch #38 start
# Epoch #39 start
# iteration 8
# Epoch #40 start
# Epoch #41 start
# Epoch #42 start
# Epoch #43 start
# Epoch #44 start
# iteration 9
# Epoch #45 start
# Epoch #46 start
# Epoch #47 start
# Epoch #48 start
# Epoch #49 start
# iteration 10
# Epoch #50 start
# Epoch #51 start
# Epoch #52 start
# Epoch #53 start
# Epoch #54 start
# iteration 11
# Epoch #55 start
# Epoch #56 start
# Epoch #57 start
# Epoch #58 start
# Epoch #59 start
# iteration 12
# Epoch #60 start
# Epoch #61 start
# Epoch #62 start
# Epoch #63 start
# Epoch #64 start
# iteration 13
# Epoch #65 start
# Epoch #66 start
# Epoch #67 start
# Epoch #68 start
# Epoch #69 start
# iteration 14
# Epoch #70 start
# Epoch #71 start
# Epoch #72 start
# Epoch #73 start
# Epoch #74 start
# iteration 15
# Epoch #75 start
# Epoch #76 start
# Epoch #77 start
# Epoch #78 start
# Epoch #79 start
# iteration 16
# Epoch #80 start
# Epoch #81 start
# Epoch #82 start
# Epoch #83 start
# Epoch #84 start
# iteration 17
# Epoch #85 start
# Epoch #86 start
# Epoch #87 start
# Epoch #88 start
# Epoch #89 start
# iteration 18
# Epoch #90 start
# Epoch #91 start
# Epoch #92 start
# Epoch #93 start
# Epoch #94 start
# iteration 19
# Epoch #95 start
# Epoch #96 start
# Epoch #97 start
# Epoch #98 start
# Epoch #99 start
# iteration 20
# Epoch #100 start
# Epoch #101 start
# Epoch #102 start
# Epoch #103 start
# Epoch #104 start
# iteration 21
# Epoch #105 start
# Epoch #106 start
# Epoch #107 start
# Epoch #108 start
# Epoch #109 start
# iteration 22
# Epoch #110 start
# Epoch #111 start
# Epoch #112 start
# Epoch #113 start
# Epoch #114 start
# iteration 23
# Epoch #115 start
# Epoch #116 start
# Epoch #117 start
# Epoch #118 start
# Epoch #119 start
# iteration 24
# Epoch #120 start
# Epoch #121 start
# Epoch #122 start
# Epoch #123 start
# Epoch #124 start
# iteration 25
# Epoch #125 start
# Epoch #126 start
# Epoch #127 start
# Epoch #128 start
# Epoch #129 start
# iteration 26
# Epoch #130 start
# Epoch #131 start
# Epoch #132 start
# Epoch #133 start
# Epoch #134 start
# iteration 27
# Epoch #135 start
# Epoch #136 start
# Epoch #137 start
# Epoch #138 start
# Epoch #139 start
# iteration 28
# Epoch #140 start
# Epoch #141 start
# Epoch #142 start
# Epoch #143 start
# Epoch #144 start
# iteration 29
# Epoch #145 start
# Epoch #146 start
# Epoch #147 start
# Epoch #148 start
# Epoch #149 start
# iteration 30
# Epoch #150 start
# Epoch #151 start
# Epoch #152 start
# Epoch #153 start
# Epoch #154 start
# iteration 31
# Epoch #155 start
# Epoch #156 start
# Epoch #157 start
# Epoch #158 start
# Epoch #159 start
# iteration 32
# Epoch #160 start
# Epoch #161 start
# Epoch #162 start
# Epoch #163 start
# Epoch #164 start
# iteration 33
# Epoch #165 start
# Epoch #166 start
# Epoch #167 start
# Epoch #168 start
# Epoch #169 start
# iteration 34
# Epoch #170 start
# Epoch #171 start
# Epoch #172 start
# Epoch #173 start
# Epoch #174 start
# iteration 35
# Epoch #175 start
# Epoch #176 start
# Epoch #177 start
# Epoch #178 start
# Epoch #179 start
# iteration 36
# Epoch #180 start
# Epoch #181 start
# Epoch #182 start
# Epoch #183 start
# Epoch #184 start
# iteration 37
# Epoch #185 start
# Epoch #186 start
# Epoch #187 start
# Epoch #188 start
# Epoch #189 start
# iteration 38
# Epoch #190 start
# Epoch #191 start
# Epoch #192 start
# Epoch #193 start
# Epoch #194 start
# iteration 39
# Epoch #195 start
# Epoch #196 start
# Epoch #197 start
# Epoch #198 start
# Epoch #199 start
# iteration 40
# Epoch #200 start
# Epoch #201 start
# Epoch #202 start
# Epoch #203 start
# Epoch #204 start
# iteration 41
# Epoch #205 start
# Epoch #206 start
# Epoch #207 start
# Epoch #208 start
# Epoch #209 start
# iteration 42
# Epoch #210 start
# Epoch #211 start
# Epoch #212 start
# Epoch #213 start
# Epoch #214 start
# iteration 43
# Epoch #215 start
# Epoch #216 start
# Epoch #217 start
# Epoch #218 start
# Epoch #219 start
# iteration 44
# Epoch #220 start
# Epoch #221 start
# Epoch #222 start
# Epoch #223 start
# Epoch #224 start
# iteration 45
# Epoch #225 start
# Epoch #226 start
# Epoch #227 start
# Epoch #228 start
# Epoch #229 start
# iteration 46
# Epoch #230 start
# Epoch #231 start
# Epoch #232 start
# Epoch #233 start
# Epoch #234 start
# iteration 47
# Epoch #235 start
# Epoch #236 start
# Epoch #237 start
# Epoch #238 start
# Epoch #239 start
# iteration 48
# Epoch #240 start
# Epoch #241 start
# Epoch #242 start
# Epoch #243 start
# Epoch #244 start
# iteration 49
# Epoch #245 start
# Epoch #246 start
# Epoch #247 start
# Epoch #248 start
# Epoch #249 start
# iteration 50
# Epoch #250 start
# Epoch #251 start
# Epoch #252 start
# Epoch #253 start
# Epoch #254 start
# iteration 51
# Epoch #255 start
# Epoch #256 start
# Epoch #257 start
# Epoch #258 start
# Epoch #259 start
# iteration 52
# Epoch #260 start
# Epoch #261 start
# Epoch #262 start
# Epoch #263 start
# Epoch #264 start
# iteration 53
# Epoch #265 start
# Epoch #266 start
# Epoch #267 start
# Epoch #268 start
# Epoch #269 start
# iteration 54
# Epoch #270 start
# Epoch #271 start
# Epoch #272 start
# Epoch #273 start
# Epoch #274 start
# iteration 55
# Epoch #275 start
# Epoch #276 start
# Epoch #277 start
# Epoch #278 start
# Epoch #279 start
# iteration 56
# Epoch #280 start
# Epoch #281 start
# Epoch #282 start
# Epoch #283 start
# Epoch #284 start
# iteration 57
# Epoch #285 start
# Epoch #286 start
# Epoch #287 start
# Epoch #288 start
# Epoch #289 start
# iteration 58
# Epoch #290 start
# Epoch #291 start
# Epoch #292 start
# Epoch #293 start
# Epoch #294 start
# iteration 59
# Epoch #295 start
# Epoch #296 start
# Epoch #297 start
# Epoch #298 start
# Epoch #299 start
# iteration 60
# Epoch #300 start
# Epoch #301 start
# Epoch #302 start
# Epoch #303 start
# Epoch #304 start
# iteration 61
# Epoch #305 start
# Epoch #306 start
# Epoch #307 start
# Epoch #308 start
# Epoch #309 start
# iteration 62
# Epoch #310 start
# Epoch #311 start
# Epoch #312 start
# Epoch #313 start
# Epoch #314 start
# iteration 63
# Epoch #315 start
# Epoch #316 start
# Epoch #317 start
# Epoch #318 start
# Epoch #319 start
# iteration 64
# Epoch #320 start
# Epoch #321 start
# Epoch #322 start
# Epoch #323 start
# Epoch #324 start
# iteration 65
# Epoch #325 start
# Epoch #326 start
# Epoch #327 start
# Epoch #328 start
# Epoch #329 start
# iteration 66
# Epoch #330 start
# Epoch #331 start
# Epoch #332 start
# Epoch #333 start
# Epoch #334 start
# iteration 67
# Epoch #335 start
# Epoch #336 start
# Epoch #337 start
# Epoch #338 start
# Epoch #339 start
# iteration 68
# Epoch #340 start
# Epoch #341 start
# Epoch #342 start
# Epoch #343 start
# Epoch #344 start
# iteration 69
# Epoch #345 start
# Epoch #346 start
# Epoch #347 start
# Epoch #348 start
# Epoch #349 start
# iteration 70
# Epoch #350 start
# Epoch #351 start
# Epoch #352 start
# Epoch #353 start
# Epoch #354 start
# iteration 71
# Epoch #355 start
# Epoch #356 start
# Epoch #357 start
# Epoch #358 start
# Epoch #359 start
# iteration 72
# Epoch #360 start
# Epoch #361 start
# Epoch #362 start
# Epoch #363 start
# Epoch #364 start
# iteration 73
# Epoch #365 start
# Epoch #366 start
# Epoch #367 start
# Epoch #368 start
# Epoch #369 start
# iteration 74
# Epoch #370 start
# Epoch #371 start
# Epoch #372 start
# Epoch #373 start
# Epoch #374 start
# iteration 75
# Epoch #375 start
# Epoch #376 start
# Epoch #377 start
# Epoch #378 start
# Epoch #379 start
# iteration 76
# Epoch #380 start
# Epoch #381 start
# Epoch #382 start
# Epoch #383 start
# Epoch #384 start
# iteration 77
# Epoch #385 start
# Epoch #386 start
# Epoch #387 start
# Epoch #388 start
# Epoch #389 start
# iteration 78
# Epoch #390 start
# Epoch #391 start
# Epoch #392 start
# Epoch #393 start
# Epoch #394 start
# iteration 79
# Epoch #395 start
# Epoch #396 start
# Epoch #397 start
# Epoch #398 start
# Epoch #399 start
# iteration 80
# Epoch #400 start
# Epoch #401 start
# Epoch #402 start
# Epoch #403 start
# Epoch #404 start
# iteration 81
# Epoch #405 start
# Epoch #406 start
# Epoch #407 start
# Epoch #408 start
# Epoch #409 start
# iteration 82
# Epoch #410 start
# Epoch #411 start
# Epoch #412 start
# Epoch #413 start
# Epoch #414 start
# iteration 83
# Epoch #415 start
# Epoch #416 start
# Epoch #417 start
# Epoch #418 start
# Epoch #419 start
# iteration 84
# Epoch #420 start
# Epoch #421 start
# Epoch #422 start
# Epoch #423 start
# Epoch #424 start
# iteration 85
# Epoch #425 start
# Epoch #426 start
# Epoch #427 start
# Epoch #428 start
# Epoch #429 start
# iteration 86
# Epoch #430 start
# Epoch #431 start
# Epoch #432 start
# Epoch #433 start
# Epoch #434 start
# iteration 87
# Epoch #435 start
# Epoch #436 start
# Epoch #437 start
# Epoch #438 start
# Epoch #439 start
# iteration 88
# Epoch #440 start
# Epoch #441 start
# Epoch #442 start
# Epoch #443 start
# Epoch #444 start
# iteration 89
# Epoch #445 start
# Epoch #446 start
# Epoch #447 start
# Epoch #448 start
# Epoch #449 start
# iteration 90
# Epoch #450 start
# Epoch #451 start
# Epoch #452 start
# Epoch #453 start
# Epoch #454 start
# iteration 91
# Epoch #455 start
# Epoch #456 start
# Epoch #457 start
# Epoch #458 start
# Epoch #459 start
# iteration 92
# Epoch #460 start
# Epoch #461 start
# Epoch #462 start
# Epoch #463 start
# Epoch #464 start
# iteration 93
# Epoch #465 start
# Epoch #466 start
# Epoch #467 start
# Epoch #468 start
# Epoch #469 start
# iteration 94
# Epoch #470 start
# Epoch #471 start
# Epoch #472 start
# Epoch #473 start
# Epoch #474 start
# iteration 95
# Epoch #475 start
# Epoch #476 start
# Epoch #477 start
# Epoch #478 start
# Epoch #479 start
# iteration 96
# Epoch #480 start
# Epoch #481 start
# Epoch #482 start
# Epoch #483 start
# Epoch #484 start
# iteration 97
# Epoch #485 start
# Epoch #486 start
# Epoch #487 start
# Epoch #488 start
# Epoch #489 start
# iteration 98
# Epoch #490 start
# Epoch #491 start
# Epoch #492 start
# Epoch #493 start
# Epoch #494 start
# iteration 99
# Epoch #495 start
# Epoch #496 start
# Epoch #497 start
# Epoch #498 start
# Epoch #499 start
# CPU times: user 1h 47min 40s, sys: 4min 29s, total: 1h 52min 10s
# Wall time: 1h 10min 29s

# %% [markdown]
# # Recommender Pipeline

# %% [markdown]
# ### Recomender by popularity

# %%
unique = 0.3 #update name
top = 20

def ranking_by_popularity(top = 100):
    
    popular_jobs = user_history.groupby(
    ['JobTitle']).size().reset_index(
    name='Count').sort_values('Count', ascending=False)
    ranking =  dict()
    top_i = 0
    
    while True:
        job_title = popular_jobs['JobTitle'].iloc[top_i]
        jobs_list = jobs.loc[jobs['Title'] == job_title, ['JobID']]['JobID'].unique().tolist()

        if len(jobs_list) > 1:
            ranking[job_title] = jobs_list

        if len(ranking) == top:
            break

        top_i +=1
    return ranking

ranking_popular = ranking_by_popularity(top = 50)

# %%
def recommender_popular_jobs(user_id,  top = 10):
    
    recommended_popular_jobs = dict()
    c1 = users.loc[users['UserID'] == user_id, 'Coordinates']
    count = 0
    if user_exist(user_id) and has_coordinates(user_id):
        for title, jobs_list in ranking_popular.items():
            
            distances = dict()
        
            for job in jobs_list:
                
                c2 = jobs.loc[jobs['JobID'] == job, 'Coordinates']
                if c2.iloc[0].split(',')[0] == 'None':
                    continue

                distances[job] = round(distance(c1, c2.iloc[0]).miles, 2)
            
            distances = sorted(distances.items(), key=lambda kv: kv[1])
            closest = distances[0]
            if closest[1] >= MAX_DISTANCE:
                continue
            recommended_popular_jobs[title] = (closest[0], closest[1])
            count += 1
            if count == top:
                break
            
        if len (recommended_popular_jobs) < top:
            count = len (recommended_popular_jobs) -1
            
            for title, jobs_list in ranking_popular.items():
                recommended_popular_jobs[title] = jobs_list[0]
                count += 1
                if count == top:
                    break

            
    else:
        for title, jobs_list in ranking_popular.items():
            recommended_popular_jobs[title] = jobs_list[0]
            count += 1
            if count == top:
                break
            
    
    
    return recommended_popular_jobs

# %% [markdown]
# ### Content Based Recommender

# %%
#If user has coordinates
#if user has info then similarties if not popularity ranker
jobID_mapping = pickle.load(open(folder+"jobID_mapping.p", "rb"))
model  = pickle.load(open(folder+"jobs_doc2vec_model", "rb"))

def content_distance_based_recommender(user_id, jobID_mapping = jobID_mapping, model =  model, top = 10):
    #As infer_vector produce stochastics result I made a for to save the best list
    user_profile = np.array(users.loc[users['UserID'] == user_id, 'profile'])[0]

    historical_apps = historical_application(user_id)
    for application in historical_apps:
        user_profile += ". " + (str(application[0]) + " ")
    user_profile = simple_preprocess(user_profile)
    
    best = 0
    tops =pd.DataFrame(index = range(top), columns = ['JobID', 'Title', 'Distance', 'Description', 'Requirements'])
    c1 = users.loc[users['UserID'] == user_id, 'Coordinates']
    job_distance_list = list()
    
    for i in range (1):
        inferred_vector = model.infer_vector(user_profile)
        sims = model.docvecs.most_similar([inferred_vector], topn=len(model.docvecs))
        sum_results = 0
        count = 0
        total_recom = 0
        job_distance_list = list()
        
        while True:
            job_id = jobID_mapping[sims[count][0]]
            c2 = jobs.loc[jobs['JobID'] == jobID_mapping[sims[count][0]], 'Coordinates']
            count +=1
            if len(c2) == 0:
                #print("Empty", sims[count][0])
                continue
            
            if c2.iloc[0].split(',')[0] == 'None':
                #print('None', sims[count][0])
                continue
                
            job_distance = round(distance(c1, c2).miles, 2)
            
            if job_distance >= MAX_DISTANCE:
                #print('Distance', job_distance,  sims[count][0])
                continue

            sum_results+=sims[count][1]
            total_recom +=1
            job_distance_list.append(job_distance)
            if total_recom == top:
                break
        
        ##Best simulation
        if sum_results > best:
            best = sum_results
            best_sim = sims
            job_distance_list2 = job_distance_list
            
    for i in range(top):
        recomendation = jobID_mapping[best_sim[i][0]]
        tops.iloc[i]['JobID', 'Title',  'Description', 'Requirements'] = np.array(jobs.loc[jobs['JobID'] == recomendation][['JobID', 'Title', 
                                                               'Description', 'Requirements']])[0]
        tops.iloc[i]['Distance'] = job_distance_list2[i]
    
    return tops 

def hybrid_recommender(user_id, top=10):
    
    if has_coordinates(user_id) and len(historical_application(user_id)) > 0:
        print("Content")
        return content_distance_based_recommender(user_id, top = top)
    else:
        print("Cold Star")
        return recommender_popular_jobs(user_id,  top = top)

# %% [markdown]
# ### Recommendation by doc2vec

# %%
user_id = 206656

print("USER PROFILE: ", user_profile(user_id))
# print("HISTORICAL APPLICATION CONTENT:\n\n", historical_application(user_id))
hybrid_recommender(user_id, top = 10)
# Out:
# USER PROFILE:
#     Degree Type: Bachelor's
#     Major: Human Resource Management
#
# Cold Star
# {'Customer Service Representative': 1015707,
#  'Cashier': 668223,
#  'Administrative Assistant': 617073,
#  'Sales Associate': 407797,
#  'Assistant Manager': 317522,
#  'Office Manager': 203695,
#  'Manager': 1097462,
#  'Receptionist': 518270,
#  'Customer Service': 119569,
#  'Store Manager': 1075099}
